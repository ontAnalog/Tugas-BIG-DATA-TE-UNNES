# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('car_purchasing.csv', encoding= 'ISO-8859-1')
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %%
df.head()
# Out:
#          age  annual Salary  credit card debt    net worth  \
# 0  41.851720    62812.09301      11609.380910  238961.2505
# 1  40.870623    66646.89292       9572.957136  530973.9078
# 2  43.152897    53798.55112      11160.355060  638467.1773
# 3  58.271369    79370.03798      14426.164850  548599.0524
# 4  57.313749    59729.15130       5358.712177  560304.0671
#
#    car purchase amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# 4          55915.46248

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  500 non-null    float64
#  1   annual Salary        500 non-null    float64
#  2   credit card debt     500 non-null    float64
#  3   net worth            500 non-null    float64
#  4   car purchase amount  500 non-null    float64
# dtypes: float64(5)
# memory usage: 19.7 KB
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %%
plt.scatter(df['annual Salary'] , df['credit card debt'])
plt.xlabel('annual Salary')
plt.ylabel('credit card debt')
plt.title('the corr between credit card debt and annual Salary')
# Out:
# Text(0.5, 1.0, 'the corr between credit card debt and annual Salary')

# %%
sns.pairplot(df)

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
scale = MinMaxScaler()
X = scale.fit_transform(X)
y = scale.fit_transform(y.values.reshape(-1, 1))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %%
#Trying linear regression
lreg = LinearRegression()
lreg.fit(X_train, y_train)
print('Train score', lreg.score(X_train, y_train))
print('Test score', lreg.score(X_test, y_test))
# Out:
# Train score 0.9999999811555402
# Test score 0.9999999810070396

# %%
y_pred = lreg.predict(X_test)

# %%
ann = Sequential([Dense(32, activation="relu"),
                 Dense(1, activation='linear')])

ann.compile(optimizer='adam',
            loss='mean_squared_error',
            metrics=['mean_absolute_error'])


history = ann.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 21ms/step - loss: 0.0543 - mean_absolute_error: 0.2037 - val_loss: 0.0245 - val_mean_absolute_error: 0.1285
# Epoch 2/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0138 - mean_absolute_error: 0.0939 - val_loss: 0.0113 - val_mean_absolute_error: 0.0872
# Epoch 3/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0113 - mean_absolute_error: 0.0837 - val_loss: 0.0123 - val_mean_absolute_error: 0.0903
# Epoch 4/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0103 - mean_absolute_error: 0.0800 - val_loss: 0.0098 - val_mean_absolute_error: 0.0810
# Epoch 5/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0082 - mean_absolute_error: 0.0707 - val_loss: 0.0087 - val_mean_absolute_error: 0.0755
# Epoch 6/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0075 - mean_absolute_error: 0.0670 - val_loss: 0.0078 - val_mean_absolute_error: 0.0712
# Epoch 7/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0066 - mean_absolute_error: 0.0625 - val_loss: 0.0068 - val_mean_absolute_error: 0.0658
# Epoch 8/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0058 - mean_absolute_error: 0.0582 - val_loss: 0.0060 - val_mean_absolute_error: 0.0612
# Epoch 9/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0051 - mean_absolute_error: 0.0544 - val_loss: 0.0053 - val_mean_absolute_error: 0.0577
# Epoch 10/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0046 - mean_absolute_error: 0.0515 - val_loss: 0.0048 - val_mean_absolute_error: 0.0544
# Epoch 11/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0042 - mean_absolute_error: 0.0492 - val_loss: 0.0043 - val_mean_absolute_error: 0.0512
# Epoch 12/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0038 - mean_absolute_error: 0.0470 - val_loss: 0.0040 - val_mean_absolute_error: 0.0494
# Epoch 13/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0034 - mean_absolute_error: 0.0446 - val_loss: 0.0035 - val_mean_absolute_error: 0.0464
# Epoch 14/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0031 - mean_absolute_error: 0.0429 - val_loss: 0.0032 - val_mean_absolute_error: 0.0447
# Epoch 15/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0028 - mean_absolute_error: 0.0411 - val_loss: 0.0030 - val_mean_absolute_error: 0.0433
# Epoch 16/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0026 - mean_absolute_error: 0.0391 - val_loss: 0.0027 - val_mean_absolute_error: 0.0412
# Epoch 17/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0023 - mean_absolute_error: 0.0374 - val_loss: 0.0024 - val_mean_absolute_error: 0.0396
# Epoch 18/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0356 - val_loss: 0.0022 - val_mean_absolute_error: 0.0382
# Epoch 19/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0019 - mean_absolute_error: 0.0339 - val_loss: 0.0020 - val_mean_absolute_error: 0.0362
# Epoch 20/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0324 - val_loss: 0.0018 - val_mean_absolute_error: 0.0349
# Epoch 21/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0306 - val_loss: 0.0016 - val_mean_absolute_error: 0.0325
# Epoch 22/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0013 - mean_absolute_error: 0.0289 - val_loss: 0.0015 - val_mean_absolute_error: 0.0314
# Epoch 23/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0272 - val_loss: 0.0013 - val_mean_absolute_error: 0.0289
# Epoch 24/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 0.0012 - val_mean_absolute_error: 0.0275
# Epoch 25/50
# 10/10 [==============================] - 0s 7ms/step - loss: 9.1760e-04 - mean_absolute_error: 0.0236 - val_loss: 9.9530e-04 - val_mean_absolute_error: 0.0253
# Epoch 26/50
# 10/10 [==============================] - 0s 6ms/step - loss: 7.8967e-04 - mean_absolute_error: 0.0221 - val_loss: 8.7103e-04 - val_mean_absolute_error: 0.0239
# Epoch 27/50
# 10/10 [==============================] - 0s 7ms/step - loss: 6.8562e-04 - mean_absolute_error: 0.0205 - val_loss: 7.6008e-04 - val_mean_absolute_error: 0.0220
# Epoch 28/50
# 10/10 [==============================] - 0s 6ms/step - loss: 6.1973e-04 - mean_absolute_error: 0.0197 - val_loss: 6.9488e-04 - val_mean_absolute_error: 0.0216
# Epoch 29/50
# 10/10 [==============================] - 0s 7ms/step - loss: 5.2732e-04 - mean_absolute_error: 0.0179 - val_loss: 5.7960e-04 - val_mean_absolute_error: 0.0193
# Epoch 30/50
# 10/10 [==============================] - 0s 5ms/step - loss: 4.5665e-04 - mean_absolute_error: 0.0168 - val_loss: 5.0683e-04 - val_mean_absolute_error: 0.0182
# Epoch 31/50
# 10/10 [==============================] - 0s 5ms/step - loss: 3.9384e-04 - mean_absolute_error: 0.0154 - val_loss: 4.4387e-04 - val_mean_absolute_error: 0.0168
# Epoch 32/50
# 10/10 [==============================] - 0s 7ms/step - loss: 3.4520e-04 - mean_absolute_error: 0.0147 - val_loss: 3.8541e-04 - val_mean_absolute_error: 0.0157
# Epoch 33/50
# 10/10 [==============================] - 0s 5ms/step - loss: 3.0854e-04 - mean_absolute_error: 0.0135 - val_loss: 3.4483e-04 - val_mean_absolute_error: 0.0147
# Epoch 34/50
# 10/10 [==============================] - 0s 5ms/step - loss: 2.6165e-04 - mean_absolute_error: 0.0128 - val_loss: 3.1059e-04 - val_mean_absolute_error: 0.0141
# Epoch 35/50
# 10/10 [==============================] - 0s 6ms/step - loss: 2.3365e-04 - mean_absolute_error: 0.0119 - val_loss: 2.7770e-04 - val_mean_absolute_error: 0.0132
# Epoch 36/50
# 10/10 [==============================] - 0s 7ms/step - loss: 2.0672e-04 - mean_absolute_error: 0.0113 - val_loss: 2.4387e-04 - val_mean_absolute_error: 0.0123
# Epoch 37/50
# 10/10 [==============================] - 0s 7ms/step - loss: 1.9278e-04 - mean_absolute_error: 0.0108 - val_loss: 2.2396e-04 - val_mean_absolute_error: 0.0118
# Epoch 38/50
# 10/10 [==============================] - 0s 7ms/step - loss: 1.7319e-04 - mean_absolute_error: 0.0103 - val_loss: 1.9542e-04 - val_mean_absolute_error: 0.0109
# Epoch 39/50
# 10/10 [==============================] - 0s 7ms/step - loss: 1.5710e-04 - mean_absolute_error: 0.0099 - val_loss: 1.8133e-04 - val_mean_absolute_error: 0.0105
# Epoch 40/50
# 10/10 [==============================] - 0s 7ms/step - loss: 1.4446e-04 - mean_absolute_error: 0.0094 - val_loss: 1.7157e-04 - val_mean_absolute_error: 0.0103
# Epoch 41/50
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3164e-04 - mean_absolute_error: 0.0091 - val_loss: 1.5726e-04 - val_mean_absolute_error: 0.0099
# Epoch 42/50
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2662e-04 - mean_absolute_error: 0.0088 - val_loss: 1.4677e-04 - val_mean_absolute_error: 0.0096
# Epoch 43/50
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1643e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3760e-04 - val_mean_absolute_error: 0.0093
# Epoch 44/50
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1260e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3553e-04 - val_mean_absolute_error: 0.0092
# Epoch 45/50
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0641e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2581e-04 - val_mean_absolute_error: 0.0089
# Epoch 46/50
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0304e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2131e-04 - val_mean_absolute_error: 0.0086
# Epoch 47/50
# 10/10 [==============================] - 0s 5ms/step - loss: 9.9330e-05 - mean_absolute_error: 0.0077 - val_loss: 1.1915e-04 - val_mean_absolute_error: 0.0087
# Epoch 48/50
# 10/10 [==============================] - 0s 6ms/step - loss: 9.5161e-05 - mean_absolute_error: 0.0077 - val_loss: 1.1229e-04 - val_mean_absolute_error: 0.0083
# Epoch 49/50
# 10/10 [==============================] - 0s 7ms/step - loss: 9.2033e-05 - mean_absolute_error: 0.0074 - val_loss: 1.0715e-04 - val_mean_absolute_error: 0.0082
# Epoch 50/50
# 10/10 [==============================] - 0s 5ms/step - loss: 8.9456e-05 - mean_absolute_error: 0.0074 - val_loss: 1.0420e-04 - val_mean_absolute_error: 0.0079

# %%
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmin(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
ann_y_pred = ann.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
r2 = r2_score(y_test, y_pred)
print('R2 score:', r2)
# Out:
# R2 score: 0.9999999810070396

# %%
ann.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1882e-04 - mean_absolute_error: 0.0081
# [0.00011881869431817904, 0.008095966652035713]

# %%
ann.predict([[40, 70000.500, 9550,534000]])
# Out:
# 1/1 [==============================] - 0s 39ms/step
# array([[234186.12]], dtype=float32)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, label='Linear Regression')
plt.scatter(y_test, ann_y_pred, label='ANN')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='gray')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs. Actual Values')
plt.legend()
plt.show()

# %%
y_pred = ann.predict(X_test)
y_pred = (y_pred > 0.5)
np.set_printoptions()
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
# Konversi variabel target kontinu menjadi label kategorikal (binning)
y_categorical = pd.cut(y.flatten(), bins=3, labels=['rendah', 'sedang', 'tinggi'])

# %%
# Bagi data menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y_categorical, test_size=0.2, random_state=42)

# %%
# Inisialisasi dan latih model klasifikasi
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Buat prediksi pada data uji
y_pred = clf.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Label yang diprediksi')
plt.ylabel('Label yang sebenarnya')
plt.title('Confusion Matrix')
plt.show()

# %%
y_pred = clf.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       rendah       0.67      0.77      0.71        13
#       sedang       0.93      0.92      0.92        71
#       tinggi       0.93      0.88      0.90        16
#
#     accuracy                           0.89       100
#    macro avg       0.84      0.85      0.85       100
# weighted avg       0.90      0.89      0.89       100
